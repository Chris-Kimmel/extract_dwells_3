# %% [markdown]
# # Extract dwell-times from fast5 base-directories
#
# Chris Kimmel, 8/6/2020 (kimmel.95@osu.edu)
#
# This code will extract dwell-times from Tombo fast5 files.
# I will use the Tombo API.
# After extracting dwell-times to CSV, I will perform a sanity check by comparing my results to results from previous attempts.
#
# Each output CSV from this notebook will correspond to a single fast5 base-directory, and will be structured as follows.
# > Each entry in the CSV file will be an integer representing the dwell-time of a particular read at a particular genomic position.
# Dwell-times are integers, not floats, because they are measured in number of raw current measurements assigned to the corresponding base.
# (Dwell-times are not measured in milliseconds.)
# >
# > The rows of the CSV file will be labeled with read ids.
# The columns will be labeled with zero-based positional indexes into the sequence of the reference fasta that was used for resquiggling.
# >
# > Fasta files are written in the 5'->3' direction, and the positional indexes will increase in this direction as well.
# (Index 0 corresponds to the furthest nucleotide on the 5' end of the reference fasta sequence.)
#
# Familiarity with the Tombo Python API is assumed throughout this notebook, but that API isn't well-documented.
# Please email me if you're reading my code and you want me to explain or clarify anything.
#
# ---
#
# ### Data source:
#
# The input data is imported from filepaths on the Ohio Supercomputer filesystem.
# It consists of directories of single-fast5 files.
# Each directory is accompanied by a Tombo index file.

# %%
import os.path
from collections import OrderedDict # Strictly for style, not functionality
import datetime

import numpy as np
import pandas as pd
from tombo import tombo_helper

# %%
fast5_basedir_path_list = [
    '/fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_A/Trizol_A_8K_single_fast5',
    '/fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_B/Trizol_B_8K_single_fast5',
    '/fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_C/Trizol_C_8K_single_fast5',
    '/fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_OLD/Trizol_OLD_8K_single_fast5',
    '/fs/project/PAS1405/GabbyLee/project/m6A_modif/ctrl_data_set/data_Olivier/f1f2_GL',
    '/fs/project/PAS1405/GabbyLee/project/m6A_modif/ctrl_data_set/data_Olivier/f1f2_subsampled',
]

reference_fasta_path = '/fs/project/PAS1405/General/Kimmel_Chris/RNA_section__454_9627.fa'

chromosome, strand = 'truncated_hiv_rna_genome', '+'
corrected_group = 'RawGenomeCorrected_000'
basecall_subgroup = 'BaseCalled_template'

# %%
fast5_basedir_path_dict = OrderedDict((os.path.basename(path), path)
                                      for path in fast5_basedir_path_list)
fast5_basedir_path_dict
# Out:
# OrderedDict([('Trizol_A_8K_single_fast5',
#               '/fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_A/Trizol_A_8K_single_fast5'),
#              ('Trizol_B_8K_single_fast5',
#               '/fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_B/Trizol_B_8K_single_fast5'),
#              ('Trizol_C_8K_single_fast5',
#               '/fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_C/Trizol_C_8K_single_fast5'),
#              ('Trizol_OLD_8K_single_fast5',
#               '/fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_OLD/Trizol_OLD_8K_single_fast5'),
#              ('f1f2_GL',
#               '/fs/project/PAS1405/GabbyLee/project/m6A_modif/ctrl_data_set/data_Olivier/f1f2_GL'),
#              ('f1f2_subsampled',
#               '/fs/project/PAS1405/GabbyLee/project/m6A_modif/ctrl_data_set/data_Olivier/f1f2_subsampled')])

# %% [markdown]
# ## Data prep

# %%
# Open all the .tombo.index files

index_dict = OrderedDict()
for name, path in fast5_basedir_path_dict.items():
    print(name)
    index_dict[name] = tombo_helper.TomboReads(
        fast5s_basedirs=[path],
        corrected_group=corrected_group,
        basecall_subgroups=[basecall_subgroup],
        # Default is basecall_subgroups=None, which makes Tombo include reads
        # from all basecall subgroups in the fast5 file. It shouldn't matter.
        for_writing=False,
        remove_filtered=True,
        # Unless told otherwise, Tombo will filter out reads with low
        # sequence-to-signal alignment. This is recorded in the index file,
        # so we use remove_filtered=True.
        sample_name=name # just for verbose output
    )
    print('')

index_dict
# Out:
# [14:48:20] Parsing Trizol_A_8K_single_fast5 Tombo index file(s).
# [14:48:20] Parsing Trizol_B_8K_single_fast5 Tombo index file(s).
# [14:48:20] Parsing Trizol_C_8K_single_fast5 Tombo index file(s).
# [14:48:20] Parsing Trizol_OLD_8K_single_fast5 Tombo index file(s).
# [14:48:20] Parsing f1f2_GL Tombo index file(s).
# Trizol_A_8K_single_fast5
#
# Trizol_B_8K_single_fast5
#
# Trizol_C_8K_single_fast5
#
# Trizol_OLD_8K_single_fast5
#
# f1f2_GL
# [14:48:23] Parsing f1f2_subsampled Tombo index file(s).
# f1f2_subsampled
# OrderedDict([('Trizol_A_8K_single_fast5',
#               <tombo.tombo_helper.TomboReads at 0x2b1a46c28d90>),
#              ('Trizol_B_8K_single_fast5',
#               <tombo.tombo_helper.TomboReads at 0x2b1a46475610>),
#              ('Trizol_C_8K_single_fast5',
#               <tombo.tombo_helper.TomboReads at 0x2b1a46bc1550>),
#              ('Trizol_OLD_8K_single_fast5',
#               <tombo.tombo_helper.TomboReads at 0x2b1a46c28a50>),
#              ('f1f2_GL', <tombo.tombo_helper.TomboReads at 0x2b1a46c283d0>),
#              ('f1f2_subsampled',
#               <tombo.tombo_helper.TomboReads at 0x2b1a46475e50>)])

# %% [markdown]
# It looks like Tombo might not have found index files for some of the reads.
# Let's just check that they're there.

# %%
for name, path in fast5_basedir_path_dict.items():
    index_basename = '.' + name + '.' + corrected_group + '.tombo.index'
    index_path = os.path.join(os.path.dirname(path), index_basename)
    if os.path.exists(index_path):
        print('The index file exists for ' + path)
    else:
        print('The index file does not exist for ' + path)
# Out:
# The index file exists for /fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_A/Trizol_A_8K_single_fast5
# The index file exists for /fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_B/Trizol_B_8K_single_fast5
# The index file exists for /fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_C/Trizol_C_8K_single_fast5
# The index file exists for /fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_OLD/Trizol_OLD_8K_single_fast5
# The index file exists for /fs/project/PAS1405/GabbyLee/project/m6A_modif/ctrl_data_set/data_Olivier/f1f2_GL
# The index file exists for /fs/project/PAS1405/GabbyLee/project/m6A_modif/ctrl_data_set/data_Olivier/f1f2_subsampled

# %% [markdown]
# Yes, all the Tombo index files exist already.
#
# As long as we're checking things, lets check our assumption that every tombo index file contains reads only for the expected chromosome and strand.

# %%
for name, index in index_dict.items():
    print(name)
    print(index.get_all_cs())
    print('')
# Out:
# Trizol_A_8K_single_fast5
# [(u'truncated_hiv_rna_genome', u'+')]
#
# Trizol_B_8K_single_fast5
# [(u'truncated_hiv_rna_genome', u'+')]
#
# Trizol_C_8K_single_fast5
# [(u'truncated_hiv_rna_genome', u'+')]
#
# Trizol_OLD_8K_single_fast5
# [(u'truncated_hiv_rna_genome', u'+')]
#
# f1f2_GL
# [(u'truncated_hiv_rna_genome', u'+')]
#
# f1f2_subsampled
# [(u'truncated_hiv_rna_genome', u'-'), (u'truncated_hiv_rna_genome', u'+')]

# %% [markdown]
# That's disturbing. The `f1f2_subsampled` fast5 base-directory has reads for the reverse strand.
#
# Let's investigate.

# %%
weird_reads = index_dict['f1f2_subsampled'].get_cs_reads(chromosome, '-')
print(len(weird_reads))
weird_reads
# Out:
# 1
# [readData(start=3, end=3872, filtered=False, read_start_rel_to_raw=417, strand=u'-', fn=u'/fs/project/PAS1405/GabbyLee/project/m6A_modif/ctrl_data_set/data_Olivier/f1f2_subsampled/f385ffd1-699e-41fe-9c02-da2a8bc8a0c6.fast5', corr_group=u'RawGenomeCorrected_000/BaseCalled_template', rna=True, sig_match_score=1.1738530947767862, mean_q_score=13.772344013490725, read_id=u'f385ffd1-699e-41fe-9c02-da2a8bc8a0c6')]

# %% [markdown]
# Evidently that was the only read on the reverse strand.
# It's surprising that the read had a `sig_match_score` of 1.17;
# that's not for `tombo resquiggle` to filter it out (under the default options at least).
#
# Maybe this molecule just went through the nanopore backwards.
# But then why doesn't this read show up on some other dataset?
#
# I'm letting it go and moving on.

# %% [markdown]
# ## Extract dwell-times
# #### (...and genomic base assignments)
#
# The point of this notebook is to extract dwell-times.
# We're also extracting genomic base assignments so that we can make sure our dwell-time data lines up perfectly with our reference genome.
#
# This section of the notebook assumes familiarity with fast5 filesin general, and fast5 "Events" datasets in particular.
#
# ---
#
# #### Digression on the "Events" table
#
# Inside the fast5 file, where the resquiggling results are stored, is an HDF5 dataset called "Events".
# This dataset is a table with several columns.
# There is one row in the Events table for every position on the reference genome sequence (i.e., the sequence from the reference fasta).
#
# One column, labeled 'base', is filled with single A's, C's, T's, and G's.
# These match the bases in the corresponding positions of the reference fasta.
# Another column, labeled 'length', gives the number of raw current measurements attributed to each nucleotide on the reference fasta.
# The length is, essentially, the dwell-time.
#
# There is no 'position' column, unfortunately, but it is easy to infer.
# To compute the zero-based reference-genome nucleotide position of a row in the table, use this rule:
# > The position of the first row of the Events table is given by
# the `start` attribute of the tombo `readData` object corresponding to the read.
# The next row of the Events table is the next position on the reference genome, and this pattern continues until the end of the read.
# >
# > The total number of rows in the Events table equals `readData.end - readData.start`.
#
# ---
#
# Here's a function to extract columns of the Events table as pandas Series.

# %%
def extract_column_as_series(read, column_name):
    '''Extract a column from the Events table of this read's fast5 file.
    
    Args:
        read (tombo.tombo_helper.readData): A Tombo readData object. The Events
            dataset in the corresponding fast5 file will be opened, and the
            specified column extracted.
        column_name (str): The name of the column to extract from the Events
            table. Options are: 'norm_mean', 'norm_stdev', 'start', 'length',
            and 'base'.
    
    Returns:
        pandas.Series: A pandas series filled with event lengths
            
            Name: The name of this series will be the read id.
            
            Index: The index labels will describe positions along the read.
            Specifically, the index label corresponding to position i on the
            reference genome will be labeled with the integer i.
            
            Like Tombo, we use zero-based indexing into the reference genome
            sequence. That is, what we call "position 0" corresponds to the
            nucleotide at the beginning of the reference FASTA.
    '''
    column = tombo_helper.get_single_slot_genome_centric(read, column_name)
    # get_single_slot_genome_centric reverses '-' strands, but that doesn't
    # matter for us since we only have '+' strands
    
    events_based_index = np.arange(len(column))
    reference_based_index = events_based_index + read.start
    
    return pd.Series(
        column,
        name=read.read_id,
        index=reference_based_index
    )

# quick test
extract_column_as_series(
    index_dict['f1f2_GL'].get_cs_reads(chromosome, strand)[0],
    'base'
).head()
# Out:
# 4597    G
# 4598    A
# 4599    T
# 4600    G
# 4601    G
# Name: 7eea708e-b3e2-4bda-b986-d2611ae50e5c, dtype: object

# %% [markdown]
# We have function that can extract a column from an individual read.
# Let's make a function that can extract a column from all the reads in a `readData` object and collate them into a single table.

# %%
def extract_column_from_all(list_of_reads, column_name):
    '''Extract `column_name` from events tables of reads in `list_of_reads`
    
    Args:
        list_of_reads (`list` of `readData`): A list of reads. It is intended
            they are all of the same chromosome and strand, but this cannot
            be checked.
    
    Returns:
        pandas.DataFrame: Dataframe filled with entries from the column
            named `column_name` in the events tables of the reads in
            `list_of_reads`.
            
            Rows are labeled with read ids. Columns are labeled with zero-based
            nucleotide-positions relative to the start of the reference fasta
            genome.
    '''
    
    return pd.concat(
        [extract_column_as_series(read, column_name)
         for read in list_of_reads],
        axis=1,
        join='outer', # default
        ignore_index=False, # default
    ).T # note the transpose


# quick test
observed = extract_column_from_all(
    index_dict['f1f2_GL'].get_cs_reads(chromosome, strand)[0:200],
    'base'
)
assert all([np.array_equal(x, y) # in python 3 add kwarg `equal_nan=True`
            for x, y in zip(observed.T, observed.T.iloc[1:,:])])
print('test successful')


observed
# Out:
# test successful
#                                      1    2    3    4    5    6    7    8     \
# 7eea708e-b3e2-4bda-b986-d2611ae50e5c  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3321a304-f6b7-46de-a9c7-6e21228ea24e  NaN  NaN  NaN  NaN  NaN  NaN    T    C
# 4774288a-63ba-46f3-83db-9782036bce6a  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3bbc2256-2c2f-4fa6-8d8d-465d88ef3cf6  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# b8519155-6299-4653-b4a2-f9b3d3b9f6bb  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 102b6260-e49a-4293-a0cd-98950a6d3741  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# d2d66b3c-fa26-4be3-889c-718c912f8848  NaN  NaN  NaN  NaN    T    C    T    C
# f8b1981e-e1b1-4376-b2d7-f52ef7a771f3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9d5514f5-3b69-414c-a64d-7efc58810d8c  NaN  NaN  NaN  NaN    T    C    T    C
# d0eee1f5-3409-434f-af36-000725ec3c9d  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 07dd332f-f6ec-429d-9af4-7d1c0c047f70  NaN  NaN  NaN  NaN    T    C    T    C
# d56d59c3-1fbd-4042-aeac-b366d4a866bb  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ff9cb552-389f-4fae-9546-bc3788fa1068  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4f0723ae-c404-4ae2-bf5e-7648a6d2e5d1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0d0905d6-403f-40fd-81ce-dce1d25db45f  NaN  NaN  NaN  NaN    T    C    T    C
# cfb0c33a-4cc6-4235-acdf-bbf8e19d31a5  NaN  NaN  NaN  NaN    T    C    T    C
# 0fae8002-dd8e-4138-9588-43010fd78f25  NaN  NaN  NaN  NaN  NaN    C    T    C
# db62c81f-f38b-4eb3-8e17-10e8d1b62f49  NaN  NaN  NaN  NaN  NaN  NaN    T    C
# ca81e805-2324-4ce5-bc7f-bc2630aed087  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 91bab69a-0972-41f7-b0c8-80a5473dc613  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 93e72f79-cf7e-498c-a78c-d02684553921  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1c607691-b252-4bfa-a66a-7509758bf82e  NaN  NaN  NaN  NaN  NaN  NaN    T    C
# 7ea158da-e99b-4f3b-b85a-d1df08df322b  NaN  NaN  NaN  NaN    T    C    T    C
# 05fcb471-9df3-45a6-8588-ac52af0a2f33  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8a023ad9-059a-45c6-bbf5-5dffaaba51c5  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 93eacc03-dfa9-4ca0-9c1e-caacd33785fb  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0a267fa8-5572-4397-84a9-fae9ad3110f8  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 84b82488-ed65-4795-bb83-689e7c30d016  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5bb5008b-0c79-4651-84a2-fa9866b0123f  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8e0c3c4e-61d7-48a4-9789-c92cdbba6dd4  NaN  NaN  NaN  NaN  NaN  NaN    T    C
# ...                                   ...  ...  ...  ...  ...  ...  ...  ...
# 93fd5356-4969-4c40-8b38-a97ff5095314  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# d7d4bc90-68fe-41b7-8983-48cd9ea8e2dc  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 29dc9e81-faa5-4ca5-947a-f3b80f85d865  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# b38b4941-a83d-4056-8f24-b480c0cc9ad8  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5cd0ed2c-6031-4c34-9f2f-8478dc13fe5e  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# fc2924ef-4836-4b4a-be74-38b399c8dc64  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# fd67448c-01cd-476a-8211-f409d5967c99  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 20818325-b3c0-4873-8d8e-f6875fe0dd8b  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 06fcff3f-2393-4398-a5b3-e6679c19efc2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 26851daf-9793-43fa-b41f-441c4a8ac7e7  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# c8278192-8ad1-40d6-a0ad-149f0b65763a  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# b02fc5b7-7c3e-45cf-97ee-c0c6d73f9004  NaN  NaN  NaN  NaN  NaN  NaN    T    C
# ff58605f-546d-4d57-a4a5-39e2a8c88544  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3e5c8f02-aeb6-4c88-b115-aefb6e44df1b  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# e3197025-c248-467a-a0a7-e28f948f6384  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# e2d56b2b-d845-49dd-81e6-87aa973f38ab  NaN  NaN  NaN    C    T    C    T    C
# 03dd8816-5abc-402a-880b-cd63e54e37ec  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2761fddd-ee57-4f96-a2e9-aa9b98f396bf  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 35defcec-bc29-4ee7-8c98-31e281962f9e  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# a569f0ab-20bb-4103-977f-472cac5f5786  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 41a054cf-66df-40dc-bcea-5e9ba42522c5  NaN  NaN  NaN  NaN    T    C    T    C
# a93fe650-3b58-49ec-a50e-bf0568b537be  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 818f6b50-3ae7-4762-bcd6-6e0369f7c8b7  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 7261819a-61b1-4ec2-b89c-1575ae05005b  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1f1f8c7f-71d4-42fc-9ce3-bc98c7bb81be  NaN  NaN  NaN  NaN  NaN  NaN  NaN    C
# d1640b4d-d131-4b0e-a6cb-91e36aff5e48  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1c81de07-f2da-4b67-81c9-179ed58955b4  NaN  NaN  NaN  NaN  NaN    C    T    C
# 149c846d-a8c9-4ad1-bc28-8d9b14dee817  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# c7d83105-a10f-48f4-839a-95a863a976f8    G    G    T    C    T    C    T    C
# bcf0c6bd-de6e-4bcf-8041-c14d6a733d3e  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                      9    10   ...  9161 9162 9163 9164 9165  \
# 7eea708e-b3e2-4bda-b986-d2611ae50e5c  NaN  NaN ...     T    T    G    A    G
# 3321a304-f6b7-46de-a9c7-6e21228ea24e    T    G ...   NaN  NaN  NaN  NaN  NaN
# 4774288a-63ba-46f3-83db-9782036bce6a  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN
# 3bbc2256-2c2f-4fa6-8d8d-465d88ef3cf6  NaN  NaN ...     T    T    G    A    G
# b8519155-6299-4653-b4a2-f9b3d3b9f6bb  NaN  NaN ...     T    T    G    A    G
# 102b6260-e49a-4293-a0cd-98950a6d3741  NaN  NaN ...     T    T    G    A    G
# d2d66b3c-fa26-4be3-889c-718c912f8848    T    G ...   NaN  NaN  NaN  NaN  NaN
# f8b1981e-e1b1-4376-b2d7-f52ef7a771f3  NaN  NaN ...     T    T    G    A    G
# 9d5514f5-3b69-414c-a64d-7efc58810d8c    T    G ...   NaN  NaN  NaN  NaN  NaN
# d0eee1f5-3409-434f-af36-000725ec3c9d  NaN    G ...   NaN  NaN  NaN  NaN  NaN
# 07dd332f-f6ec-429d-9af4-7d1c0c047f70    T    G ...   NaN  NaN  NaN  NaN  NaN
# d56d59c3-1fbd-4042-aeac-b366d4a866bb  NaN  NaN ...     T    T    G    A    G
# ff9cb552-389f-4fae-9546-bc3788fa1068  NaN  NaN ...     T    T    G    A    G
# 4f0723ae-c404-4ae2-bf5e-7648a6d2e5d1  NaN  NaN ...     T    T    G    A    G
# 0d0905d6-403f-40fd-81ce-dce1d25db45f    T    G ...   NaN  NaN  NaN  NaN  NaN
# cfb0c33a-4cc6-4235-acdf-bbf8e19d31a5    T    G ...   NaN  NaN  NaN  NaN  NaN
# 0fae8002-dd8e-4138-9588-43010fd78f25    T    G ...   NaN  NaN  NaN  NaN  NaN
# db62c81f-f38b-4eb3-8e17-10e8d1b62f49    T    G ...   NaN  NaN  NaN  NaN  NaN
# ca81e805-2324-4ce5-bc7f-bc2630aed087  NaN  NaN ...     T    T    G    A    G
# 91bab69a-0972-41f7-b0c8-80a5473dc613  NaN  NaN ...     T    T    G    A    G
# 93e72f79-cf7e-498c-a78c-d02684553921  NaN  NaN ...     T    T    G    A    G
# 1c607691-b252-4bfa-a66a-7509758bf82e    T    G ...   NaN  NaN  NaN  NaN  NaN
# 7ea158da-e99b-4f3b-b85a-d1df08df322b    T    G ...   NaN  NaN  NaN  NaN  NaN
# 05fcb471-9df3-45a6-8588-ac52af0a2f33  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN
# 8a023ad9-059a-45c6-bbf5-5dffaaba51c5  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN
# 93eacc03-dfa9-4ca0-9c1e-caacd33785fb  NaN  NaN ...     T    T    G    A    G
# 0a267fa8-5572-4397-84a9-fae9ad3110f8  NaN  NaN ...     T    T    G    A    G
# 84b82488-ed65-4795-bb83-689e7c30d016  NaN    G ...   NaN  NaN  NaN  NaN  NaN
# 5bb5008b-0c79-4651-84a2-fa9866b0123f  NaN  NaN ...     T    T    G    A    G
# 8e0c3c4e-61d7-48a4-9789-c92cdbba6dd4    T    G ...   NaN  NaN  NaN  NaN  NaN
# ...                                   ...  ... ...   ...  ...  ...  ...  ...
# 93fd5356-4969-4c40-8b38-a97ff5095314  NaN  NaN ...     T    T    G    A    G
# d7d4bc90-68fe-41b7-8983-48cd9ea8e2dc  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN
# 29dc9e81-faa5-4ca5-947a-f3b80f85d865  NaN  NaN ...     T    T    G    A    G
# b38b4941-a83d-4056-8f24-b480c0cc9ad8  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN
# 5cd0ed2c-6031-4c34-9f2f-8478dc13fe5e  NaN  NaN ...     T    T    G    A    G
# fc2924ef-4836-4b4a-be74-38b399c8dc64  NaN  NaN ...     T    T    G    A    G
# fd67448c-01cd-476a-8211-f409d5967c99  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN
# 20818325-b3c0-4873-8d8e-f6875fe0dd8b  NaN  NaN ...     T    T    G    A    G
# 06fcff3f-2393-4398-a5b3-e6679c19efc2  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN
# 26851daf-9793-43fa-b41f-441c4a8ac7e7    T    G ...   NaN  NaN  NaN  NaN  NaN
# c8278192-8ad1-40d6-a0ad-149f0b65763a  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN
# b02fc5b7-7c3e-45cf-97ee-c0c6d73f9004    T    G ...   NaN  NaN  NaN  NaN  NaN
# ff58605f-546d-4d57-a4a5-39e2a8c88544  NaN  NaN ...     T    T    G    A    G
# 3e5c8f02-aeb6-4c88-b115-aefb6e44df1b  NaN    G ...   NaN  NaN  NaN  NaN  NaN
# e3197025-c248-467a-a0a7-e28f948f6384  NaN  NaN ...     T    T    G    A    G
# e2d56b2b-d845-49dd-81e6-87aa973f38ab    T    G ...   NaN  NaN  NaN  NaN  NaN
# 03dd8816-5abc-402a-880b-cd63e54e37ec  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN
# 2761fddd-ee57-4f96-a2e9-aa9b98f396bf  NaN  NaN ...     T    T    G    A    G
# 35defcec-bc29-4ee7-8c98-31e281962f9e  NaN  NaN ...     T    T    G    A    G
# a569f0ab-20bb-4103-977f-472cac5f5786  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN
# 41a054cf-66df-40dc-bcea-5e9ba42522c5    T    G ...   NaN  NaN  NaN  NaN  NaN
# a93fe650-3b58-49ec-a50e-bf0568b537be  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN
# 818f6b50-3ae7-4762-bcd6-6e0369f7c8b7  NaN  NaN ...     T    T    G    A    G
# 7261819a-61b1-4ec2-b89c-1575ae05005b  NaN  NaN ...     T    T    G    A    G
# 1f1f8c7f-71d4-42fc-9ce3-bc98c7bb81be    T    G ...   NaN  NaN  NaN  NaN  NaN
# d1640b4d-d131-4b0e-a6cb-91e36aff5e48    T    G ...   NaN  NaN  NaN  NaN  NaN
# 1c81de07-f2da-4b67-81c9-179ed58955b4    T    G ...   NaN  NaN  NaN  NaN  NaN
# 149c846d-a8c9-4ad1-bc28-8d9b14dee817  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN
# c7d83105-a10f-48f4-839a-95a863a976f8    T    G ...   NaN  NaN  NaN  NaN  NaN
# bcf0c6bd-de6e-4bcf-8041-c14d6a733d3e  NaN  NaN ...   NaN  NaN  NaN  NaN  NaN
#
#                                      9166 9167 9168 9169 9170
# 7eea708e-b3e2-4bda-b986-d2611ae50e5c    T    G    C    T    T
# 3321a304-f6b7-46de-a9c7-6e21228ea24e  NaN  NaN  NaN  NaN  NaN
# 4774288a-63ba-46f3-83db-9782036bce6a  NaN  NaN  NaN  NaN  NaN
# 3bbc2256-2c2f-4fa6-8d8d-465d88ef3cf6    T    G    C    T  NaN
# b8519155-6299-4653-b4a2-f9b3d3b9f6bb    T    G    C    T    T
# 102b6260-e49a-4293-a0cd-98950a6d3741    T    G    C    T  NaN
# d2d66b3c-fa26-4be3-889c-718c912f8848  NaN  NaN  NaN  NaN  NaN
# f8b1981e-e1b1-4376-b2d7-f52ef7a771f3    T    G    C    T  NaN
# 9d5514f5-3b69-414c-a64d-7efc58810d8c  NaN  NaN  NaN  NaN  NaN
# d0eee1f5-3409-434f-af36-000725ec3c9d  NaN  NaN  NaN  NaN  NaN
# 07dd332f-f6ec-429d-9af4-7d1c0c047f70  NaN  NaN  NaN  NaN  NaN
# d56d59c3-1fbd-4042-aeac-b366d4a866bb    T    G    C    T  NaN
# ff9cb552-389f-4fae-9546-bc3788fa1068    T    G    C    T  NaN
# 4f0723ae-c404-4ae2-bf5e-7648a6d2e5d1    T    G    C    T  NaN
# 0d0905d6-403f-40fd-81ce-dce1d25db45f  NaN  NaN  NaN  NaN  NaN
# cfb0c33a-4cc6-4235-acdf-bbf8e19d31a5  NaN  NaN  NaN  NaN  NaN
# 0fae8002-dd8e-4138-9588-43010fd78f25  NaN  NaN  NaN  NaN  NaN
# db62c81f-f38b-4eb3-8e17-10e8d1b62f49  NaN  NaN  NaN  NaN  NaN
# ca81e805-2324-4ce5-bc7f-bc2630aed087    T    G    C    T    T
# 91bab69a-0972-41f7-b0c8-80a5473dc613    T    G    C    T  NaN
# 93e72f79-cf7e-498c-a78c-d02684553921    T    G    C    T    T
# 1c607691-b252-4bfa-a66a-7509758bf82e  NaN  NaN  NaN  NaN  NaN
# 7ea158da-e99b-4f3b-b85a-d1df08df322b  NaN  NaN  NaN  NaN  NaN
# 05fcb471-9df3-45a6-8588-ac52af0a2f33  NaN  NaN  NaN  NaN  NaN
# 8a023ad9-059a-45c6-bbf5-5dffaaba51c5  NaN  NaN  NaN  NaN  NaN
# 93eacc03-dfa9-4ca0-9c1e-caacd33785fb    T    G    C    T    T
# 0a267fa8-5572-4397-84a9-fae9ad3110f8    T    G  NaN  NaN  NaN
# 84b82488-ed65-4795-bb83-689e7c30d016  NaN  NaN  NaN  NaN  NaN
# 5bb5008b-0c79-4651-84a2-fa9866b0123f    T    G    C    T  NaN
# 8e0c3c4e-61d7-48a4-9789-c92cdbba6dd4  NaN  NaN  NaN  NaN  NaN
# ...                                   ...  ...  ...  ...  ...
# 93fd5356-4969-4c40-8b38-a97ff5095314    T    G    C  NaN  NaN
# d7d4bc90-68fe-41b7-8983-48cd9ea8e2dc  NaN  NaN  NaN  NaN  NaN
# 29dc9e81-faa5-4ca5-947a-f3b80f85d865    T    G  NaN  NaN  NaN
# b38b4941-a83d-4056-8f24-b480c0cc9ad8  NaN  NaN  NaN  NaN  NaN
# 5cd0ed2c-6031-4c34-9f2f-8478dc13fe5e    T    G    C    T  NaN
# fc2924ef-4836-4b4a-be74-38b399c8dc64    T    G    C    T  NaN
# fd67448c-01cd-476a-8211-f409d5967c99  NaN  NaN  NaN  NaN  NaN
# 20818325-b3c0-4873-8d8e-f6875fe0dd8b    T    G    C    T    T
# 06fcff3f-2393-4398-a5b3-e6679c19efc2  NaN  NaN  NaN  NaN  NaN
# 26851daf-9793-43fa-b41f-441c4a8ac7e7  NaN  NaN  NaN  NaN  NaN
# c8278192-8ad1-40d6-a0ad-149f0b65763a  NaN  NaN  NaN  NaN  NaN
# b02fc5b7-7c3e-45cf-97ee-c0c6d73f9004  NaN  NaN  NaN  NaN  NaN
# ff58605f-546d-4d57-a4a5-39e2a8c88544    T    G    C    T  NaN
# 3e5c8f02-aeb6-4c88-b115-aefb6e44df1b  NaN  NaN  NaN  NaN  NaN
# e3197025-c248-467a-a0a7-e28f948f6384    T    G    C    T  NaN
# e2d56b2b-d845-49dd-81e6-87aa973f38ab  NaN  NaN  NaN  NaN  NaN
# 03dd8816-5abc-402a-880b-cd63e54e37ec  NaN  NaN  NaN  NaN  NaN
# 2761fddd-ee57-4f96-a2e9-aa9b98f396bf    T    G    C    T  NaN
# 35defcec-bc29-4ee7-8c98-31e281962f9e    T    G    C    T    T
# a569f0ab-20bb-4103-977f-472cac5f5786  NaN  NaN  NaN  NaN  NaN
# 41a054cf-66df-40dc-bcea-5e9ba42522c5  NaN  NaN  NaN  NaN  NaN
# a93fe650-3b58-49ec-a50e-bf0568b537be  NaN  NaN  NaN  NaN  NaN
# 818f6b50-3ae7-4762-bcd6-6e0369f7c8b7    T    G    C    T    T
# 7261819a-61b1-4ec2-b89c-1575ae05005b    T    G    C    T  NaN
# 1f1f8c7f-71d4-42fc-9ce3-bc98c7bb81be  NaN  NaN  NaN  NaN  NaN
# d1640b4d-d131-4b0e-a6cb-91e36aff5e48  NaN  NaN  NaN  NaN  NaN
# 1c81de07-f2da-4b67-81c9-179ed58955b4  NaN  NaN  NaN  NaN  NaN
# 149c846d-a8c9-4ad1-bc28-8d9b14dee817  NaN  NaN  NaN  NaN  NaN
# c7d83105-a10f-48f4-839a-95a863a976f8  NaN  NaN  NaN  NaN  NaN
# bcf0c6bd-de6e-4bcf-8041-c14d6a733d3e  NaN  NaN  NaN  NaN  NaN
#
# [200 rows x 9162 columns]

# %% [markdown]
# Now we have enough tools to extract the desired table of dwell times from each fast5 base-directory.

# %%
# took about two hours (Owens cluster, 1 node, 28 cores, plain vanilla filestystem)
# to cut the processing time in half, comment out the base_table lines

length_table_dict = OrderedDict()
base_table_dict = OrderedDict()
for name, index in index_dict.items():
    print(name)
    list_of_reads = index.get_cs_reads(chromosome, strand)
    print('extracting length table...')
    length_table_dict[name] = extract_column_from_all(list_of_reads, 'length')
    print('extracting base table...')
    base_table_dict[name] = extract_column_from_all(list_of_reads, 'base')
    print('')
print('done')
# Out:
# Trizol_A_8K_single_fast5
# extracting length table...
# extracting base table...
#
# Trizol_B_8K_single_fast5
# extracting length table...
# extracting base table...
#
# Trizol_C_8K_single_fast5
# extracting length table...
# extracting base table...
#
# Trizol_OLD_8K_single_fast5
# extracting length table...
# extracting base table...
#
# f1f2_GL
# extracting length table...
# extracting base table...
#
# f1f2_subsampled
# extracting length table...
# extracting base table...
#
# done

# %% [markdown]
# Now it's time to output the length tables to CSV files.

# %%
for name, length_table in length_table_dict.items():
    print(name)
    output_filename = name + '_dwells.csv'
    length_table.to_csv(
        output_filename,
        sep=',', # default
        na_rep='nan',
        header=True,
        index=True,
        index_label='read_id'
    )
    print('')
print('done')
# Out:
# Trizol_A_8K_single_fast5
#
# Trizol_B_8K_single_fast5
#
# Trizol_C_8K_single_fast5
#
# Trizol_OLD_8K_single_fast5
#
# f1f2_GL
#
# f1f2_subsampled
#
# done

# %% [markdown]
# The above code seems to print CSV files full of entries that look like "12.0" instead of "12".
# You could cut down the size of the CSV files considerably if you fixed that...

# %% [markdown]
# ## Sanity checks

# %% [markdown]
# ### Reference FASTA
#
# Let's check the base tables against the reference genome to make sure the position-numbers are correct.

# %%
# Get reference sequence as a pandas Series

with open(reference_fasta_path, 'rt') as file:
    lines = file.readlines()
    
reference_sequence = lines[1].strip().upper()
reference_sequence_series = pd.Series(
    list(reference_sequence),
    index=np.arange(len(reference_sequence))
)

reference_sequence_series
# Out:
# 0       G
# 1       G
# 2       G
# 3       T
# 4       C
# 5       T
# 6       C
# 7       T
# 8       C
# 9       T
# 10      G
# 11      G
# 12      T
# 13      T
# 14      A
# 15      G
# 16      A
# 17      C
# 18      C
# 19      A
# 20      G
# 21      A
# 22      T
# 23      C
# 24      T
# 25      G
# 26      A
# 27      G
# 28      C
# 29      C
#        ..
# 9144    C
# 9145    C
# 9146    T
# 9147    C
# 9148    A
# 9149    A
# 9150    T
# 9151    A
# 9152    A
# 9153    A
# 9154    G
# 9155    C
# 9156    T
# 9157    T
# 9158    G
# 9159    C
# 9160    C
# 9161    T
# 9162    T
# 9163    G
# 9164    A
# 9165    G
# 9166    T
# 9167    G
# 9168    C
# 9169    T
# 9170    T
# 9171    C
# 9172    A
# 9173    A
# Length: 9174, dtype: object

# %%
# Compare each row of base_table to the reference series
# Admittedly, this probably uses more computation than is really necessary

# This cell did not finish, even after three hours (Owens Cluster, 1 node, 28 cores)

for name, base_table in base_table_dict.items():
    print(name)
    for index, row in base_table.iterrows():
        # combine dataframes so they have the same index
        df = pd.DataFrame([row, reference_sequence_series])
        obs_bases = df.iloc[0, :].values.astype('U')
        ref_bases = df.iloc[1, :].values.astype('U')
        # Check that our bases equal the reference genome bases.
        # Make exceptions for bases that aren't defined.
        assert np.all((obs_bases == ref_bases)
                      | (obs_bases == 'nan').astype('?')
                     ), index
print('test passed')
# Out:
# Trizol_A_8K_single_fast5
# Trizol_B_8K_single_fast5
# Trizol_C_8K_single_fast5
# Trizol_OLD_8K_single_fast5
# f1f2_GL
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-228-1747c1777fdc> in <module>()
#       3     for index, row in base_table.iterrows():
#       4         # combine dataframes so they have the same index
# ----> 5         df = pd.DataFrame([row, reference_sequence_series])
#       6         obs_bases = df.iloc[0, :].values.astype('U')
#       7         ref_bases = df.iloc[1, :].values.astype('U')
#
# /users/PAS1405/kimmel/.conda/envs/tombo2/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     367                     if is_named_tuple(data[0]) and columns is None:
#     368                         columns = data[0]._fields
# --> 369                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     370                     columns = _ensure_index(columns)
#     371
#
# /users/PAS1405/kimmel/.conda/envs/tombo2/lib/python2.7/site-packages/pandas/core/frame.pyc in _to_arrays(data, columns, coerce_float, dtype)
#    6289         return _list_of_series_to_arrays(data, columns,
#    6290                                          coerce_float=coerce_float,
# -> 6291                                          dtype=dtype)
#    6292     elif isinstance(data[0], Categorical):
#    6293         if columns is None:
#
# /users/PAS1405/kimmel/.conda/envs/tombo2/lib/python2.7/site-packages/pandas/core/frame.pyc in _list_of_series_to_arrays(data, columns, coerce_float, dtype)
#    6391         content = list(values.T)
#    6392         return _convert_object_array(content, columns, dtype=dtype,
# -> 6393                                      coerce_float=coerce_float)
#    6394     else:
#    6395         return values.T, columns
#
# /users/PAS1405/kimmel/.conda/envs/tombo2/lib/python2.7/site-packages/pandas/core/frame.pyc in _convert_object_array(content, columns, coerce_float, dtype)
#    6427         return arr
#    6428
# -> 6429     arrays = [convert(arr) for arr in content]
#    6430
#    6431     return arrays, columns
#
# /users/PAS1405/kimmel/.conda/envs/tombo2/lib/python2.7/site-packages/pandas/core/frame.pyc in convert(arr)
#    6424         if dtype != object and dtype != np.object:
#    6425             arr = lib.maybe_convert_objects(arr, try_float=coerce_float)
# -> 6426             arr = maybe_cast_to_datetime(arr, dtype)
#    6427         return arr
#    6428
#
# /users/PAS1405/kimmel/.conda/envs/tombo2/lib/python2.7/site-packages/pandas/core/dtypes/cast.pyc in maybe_cast_to_datetime(value, dtype, errors)
#    1042         elif not (is_array and not (issubclass(value.dtype.type, np.integer) or
#    1043                                     value.dtype == np.object_)):
# -> 1044             value = maybe_infer_to_datetimelike(value)
#    1045
#    1046     return value
#
# /users/PAS1405/kimmel/.conda/envs/tombo2/lib/python2.7/site-packages/pandas/core/dtypes/cast.pyc in maybe_infer_to_datetimelike(value, convert_dates)
#     856     if isinstance(value, (ABCDatetimeIndex, ABCPeriodIndex)):
#     857         return value
# --> 858     elif isinstance(value, ABCSeries):
#     859         if isinstance(value._values, ABCDatetimeIndex):
#     860             return value._values
#
# /users/PAS1405/kimmel/.conda/envs/tombo2/lib/python2.7/site-packages/pandas/core/dtypes/generic.pyc in _check(cls, inst)
#       5 # objects
#       6 def create_pandas_abc_type(name, attr, comp):
# ----> 7     @classmethod
#       8     def _check(cls, inst):
#       9         return getattr(inst, attr, '_typ') in comp
#
# KeyboardInterrupt:

# %% [markdown]
# I interrupted execute of the preceeding cell after about three hours.
# It verified that the bases matched the reference genome for all these samples:
# * Trizol_A_8K_single_fast5
# * Trizol_B_8K_single_fast5
# * Trizol_C_8K_single_fast5
# * Trizol_OLD_8K_single_fast5
#
# Unfortunately f1f2_GL, with over 100,000 samples, was just taking too dang long.

# %% [markdown]
# ### Previous work
#
# Let's make sure our new tables agree with similar tables produced by earlier code.
#
# Two things need to be noted:
# 1. Earlier code did not filter out reads with poor sequence-to-signal alignment, so earlier CSV files will include reads that aren't in our new tables.
# 2. Some (but not all) earlier datasets had rows labeled like "3154b6e-f9cc-4e3b-8c2c-5f0fa43de9c2.fast5", but we label them like "13154b6e-f9cc-4e3b-8c2c-5f0fa43de9c2" (without the .fast5 extension).
#
# I will just load one CSV produced from earlier code.
# The complexity of checking several isn't worth it.

# %%
earlier_csv_path = '/users/PAS1405/kimmel/extract_dwells_2/Trizol_B_lengths.csv'
corresponding_name = 'Trizol_B_8K_single_fast5'

earlier_csv_dataframe = pd.read_csv(
    earlier_csv_path,
    header=0,
    index_col=0
)

# Correct the incorrect index labels
earlier_csv_dataframe.index = earlier_csv_dataframe.index.map(
    lambda x: x.split('.')[0]
)
earlier_csv_dataframe.columns = earlier_csv_dataframe.columns.astype(np.dtype(int))

# Check that new reads agree with old reads
for read_id, row in length_table_dict[corresponding_name].iterrows():
    earlier_row = earlier_csv_dataframe.loc[read_id, :]
    assert all(
        (earlier_row == row)
        | (earlier_row.isna() & row.isna())
    ), read_id

# Check that the neither table is very much bigger than the other
ratio = len(earlier_csv_dataframe)/len(length_table_dict[corresponding_name])
assert 0.8 < ratio < 1.2, ratio
print('test passed')
# Out:
# test passed

# %% [markdown]
# ### Filtered reads
#
# Let's make sure that filtered reads were not included in the output tables

# %%
for name in index_dict.keys():
    print(name)
    
    index = index_dict[name]
    filtered_read_ids = [read.read_id for read in index.get_cs_reads(chromosome, strand) if read.filtered]
    unfiltered_read_ids = [read.read_id for read in index.get_cs_reads(chromosome, strand) if not read.filtered]
    
    # check that NONE of the FILTERED reads are represented in the index of the dwell-time table
    length_table_index_set = set(length_table_dict[name].index)
    if all([read_id not in length_table_index_set for read_id in filtered_read_ids]):
        pass
    else:
        print('test 1 failed: ' + name)
    
    # check that ALL of the UNFILTERED read ids are represented in the index of the dwell-time table
    if all([read_id in length_table_index_set for read_id in unfiltered_read_ids]):
        pass
    else:
        print('test 2 failed: ' + name)
# Out:
# Trizol_A_8K_single_fast5
# Trizol_B_8K_single_fast5
# Trizol_C_8K_single_fast5
# Trizol_OLD_8K_single_fast5
# f1f2_GL
# f1f2_subsampled

# %% [markdown]
# This test also passed. So the dwell-times passed all our tests, and we'll consider them correct.

# %% [markdown]
# ## KS Tests
#
# This is not related to anything else in the notebook; I just wanted to try it.
# This is a positional two-sample KS test of Trizol A reads against f1f2 reads.

# %%
pos = 1234
sample_A = length_table_dict['Trizol_A_8K_single_fast5'].loc[:, pos].dropna()
sample_B = length_table_dict['f1f2_subsampled'].loc[:, pos].dropna()

print(len(sample_A))
print(len(sample_B))

import scipy.stats as stats
stats.ks_2samp(sample_A, sample_B)
# Out:
# 392
# 3441
# Ks_2sampResult(statistic=0.12666806042382084, pvalue=2.141212982034808e-05)
